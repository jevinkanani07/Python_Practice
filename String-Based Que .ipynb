# %% [markdown]
# # String-Based Que

# %%
phone5 = [3,20,24,28]

# %% [markdown]
# #### 1. write a python programm to reverse a string.

# %%
a = str(input("enter any name :-"))
b = a[::-1]
print("revers a string :-",b)
# Out:
# enter any name :- jevin
# revers a string :- nivej

# %% [markdown]
# #### 2. write a python programm to check if a string is a pailndrome.

# %%
a = str(input("enter any name :-")).lower()
if a==a[::-1]:
    print("your string is a pailndrome")
else:
    print("your string is a not pailndrome")
# Out:
# enter any name :- kanani
# your string is a not pailndrome

# %% [markdown]
# #### 4. write a python programm to find the length of a string.

# %%
str = "jevin kanani"

print(len(str))
# Out:
# 12

# %% [markdown]
# #### 5 . write a python programm ro concatenate two strings.

# %%
str1 = "jevin"
str2 = "kanani"

str = str1 + str2
print("concatenate two strings :",str)
# Out:
# concatenate two strings : jevinkanani

# %% [markdown]
# #### 6.write a python programm to convert a string to uppercase.

# %%
str = "jevin kanani"

a = str.upper()
print(a)
# Out:
# JEVIN KANANI

# %% [markdown]
# #### 7.write a python program to convert a string to loewrcase.

# %%
str = "jeVin kanAni"

a = str.lower()
print(a)
# Out:
# jevin kanani

# %% [markdown]
# #### 8. write a python programm to capitalize the first letter of a string.

# %%
str = "jevin kanani"

a = str.capitalize()
print(a)
# Out:
# Jevin kanani

# %% [markdown]
# #### 9.write a python programm to count the occurrences in a string.

# %%
str = "jevin kanani"

a = input("enter the occurrences in a string to get count :-")
b = str.count(a)
print("the character is a count the occurrences in a string ",b)
# Out:
# enter the occurrences in a string to get count :- jevin
# the character is a count the occurrences in a string  1

# %% [markdown]
# #### 10. write a python programm to find the index of  substring in a string

# %%
str = "jevin kanani"

a = input("enter a name to find a index :-")

b = str.index(a)

print("your string a find index number :-",b)
# Out:
# enter a name to find a index :- jevin kanani
# your string a find index number :- 0

# %% [markdown]
# #### 11. write a python programm to check if a contains only digits.

# %%
a = input("Enter a string ")

if a.isdigit():
    print("the string is contanis only digits")
else:
    print("the string does not contain only digits")
# Out:
# Enter a string  k jevin
# the string does not contain only digits

# %% [markdown]
# #### 12.write a python programm to check if a string contains only alphabetic characters.

# %%
a = input("enter a string :-")

if a.isalpha():
    print("the string is only alphabetic characters")
else:
    print("the string is not only alphabetic characters")
# Out:
# enter a string :- jevin k
# the string is not only alphabetic characters

# %% [markdown]
# #### 13. write a python programm to replace a specific character in a string.

# %%
a = input("enter a string :-")
b = input("enter a old character to replace :-")
c = input("enter a new character in a string :-")

d = a.replace(b,c)
print("your character is replace is a :-",d)
# Out:
# enter a string :- data science
# enter a old character to replace :- data
# enter a new character in a string :- computer
# your character is replace is a :- computer science

# %% [markdown]
# #### 14. write a python programm to remove leading and trailing whitespaces from a string.

# %%
a = input("enter a string :-")

b = a.strip()

print("string after removing white space :-",b)
# Out:
# enter a string :- data science in ai
# string after removing white space :- data science in ai

# %% [markdown]
# #### 15. write a python programm to split a string into a list of words.

# %%
a = input("enter a string :-")
b = a.split()
print("after a split a string into a list :-",b)
# Out:
# enter a string :- history
# after a split a string into a list :- ['history']

# %% [markdown]
# #### 16. write a python programm to join a list of strings into a single strings.

# %%
l1 = ["jevin","ahemdabad"]

a = " ".join(l1)
print("joined stringd :-",a)
# Out:
# joined stringd :- jevin ahemdabad

# %% [markdown]
# #### 17. write a python programm to find the position of the occurrence of a character in a string.

# %%
a = input("enter a string :-")
b = input("enter a charater to find :")
c = a.count(b)
if c != -1:
    print("first occurrence of ",b,"is at index ",c,)
else:
    print("charater not fond")
# Out:
# enter a string :- machine learning
# enter a charater to find : l
# first occurrence of  l is at index  1

# %% [markdown]
# #### 18. write a python programm to check if a string starts with a specific character.

# %%
a = input("enter a string :-")
b = input("enter a start character :-")
c = a.startswith(b)
print("start with ",b,"?",c)
# Out:
# enter a string :- data acience
# enter a start character :- a
# start with  a ? False

# %% [markdown]
# #### 19. write a pyhton programm to check if a string ends with a specific character.

# %%
a = input("enter a name :-")
b = input("enter a end charatcer :-")
c=  a.endswith(b)
print("start with ",b,"?",c)
# Out:
# enter a name :- deep learning
# enter a end charatcer :- p
# start with  p ? False

# %% [markdown]
# #### 21. write a python programm to convert a string into a list of character.

# %%
a = input("enter a name ")
b = list(a)
print("convert a string into a list of character :-",b)
# Out:
# enter a name  string
# convert a string into a list of character :- ['s', 't', 'r', 'i', 'n', 'g']

# %% [markdown]
# #### 22.write a python programm to remove all occurrences of a specific character in a string.

# %%
a = input("enter a name :-")
b = input("enter a which number to remove a string")
c = a.replace(b," ")
print("a remove specific character in a string",c)
# Out:
# enter a name :- function
# enter a which number to remove a string o
# a remove specific character in a string functi n

# %% [markdown]
# #### 23. write a python programm to count the number of words in a string.

# %%
a = input("enter a number  :-")
b = len(a)
print("the number count is a :-",b)
# Out:
# enter a number  :- machine learning is very important for data science
# the number count is a :- 52

# %% [markdown]
# #### 24. write a python programm to repeat a string a certain number of times.

# %%
a = input("enter a name")
b = int(input("enter a certain number to repeat :-"))
c = a * b
print("repeated time ", c)
# Out:
# enter a name python
# enter a certain number to repeat :- 1
# repeated time  python

# %% [markdown]
# #### 25. write a python programm to swap the case of a string

# %%
a = input("enter a name")
b = a.swapcase()
print("swapped case :",b)
# Out:
# enter a name libarary
# swapped case : LIBARARY

# %% [markdown]
# #### 26. write a python programm to check if a string is a vaild integer.

# %%
a = input("enter a number :-")
b = a.isdigit()
print("is vaild integer ?",b)
# Out:
# enter a number :- programm
# is vaild integer ? False

# %% [markdown]
# #### 27.write a python programm to capitalize the first letter of each word in a string.

# %%
a = input("enter a name ")
b = a.capitalize()
print("your first letter is a capitalize :-",b)
# Out:
# enter a name  jevin kanani
# your first letter is a capitalize :- Jevin kanani
