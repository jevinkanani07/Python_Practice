# %% [markdown]
# # Dictionary-Based Que

# %%
phone4 = [23,24,25]

# %% [markdown]
# #### 1. write a python programm to create a dicionary

# %%
dic = {
    "name":"jevin",
    "age":18,
    "add":"ahemdabad",
}

# %%
print(dic)
# Out:
# {'name': 'jevin', 'age': 18, 'add': 'ahemdabad'}

# %% [markdown]
# #### 2. write a python programm to access an item in a dictionary

# %%
dic = {
    "name":"jevin",
    "age":18,
    "add":"ahemdabad",
}

# %%
name = dic["name"]
age = dic["age"]

# %%
print("Name : ",name)
print("Age :",age)
# Out:
# Name :  jevin
# Age : 18

# %% [markdown]
# #### 3. write a python programm to find the length of a dictionary

# %%
dic = {
    "name":"jevin",
    "age":18,
    "add":"ahemdabad",
}

print(len(dic))
# Out:
# 3

# %% [markdown]
# #### 4. write a python programm to add a key-value pair to a dictionary.

# %%
dic = {
    "name":"jevin",
    "age":18,
    "add":"ahemdabad",
}

dic["country"] = "india"

print("after add a dic",dic)
# Out:
# after add a dic {'name': 'jevin', 'age': 18, 'add': 'ahemdabad', 'country': 'india'}

# %% [markdown]
# #### 5. write a python programm to update a key-value pair in a dictionary.

# %%
dic = {
    "name":"jevin",
    "age":18,
    "add":"ahemdabad",
}

dic["age"] = 19

print("after a update a dic :-",dic)
# Out:
# after a update a dic :- {'name': 'jevin', 'age': 19, 'add': 'ahemdabad'}

# %% [markdown]
# #### 6. write a python programm to remove a key from a dictionary

# %%
dic = {
    "name":"jevin",
    "age":18,
    "add":"ahemdabad",
}

del dic["add"]

print("after a delect add :-",dic)
# Out:
# after a delect add :- {'name': 'jevin', 'age': 18}

# %% [markdown]
# #### 7. write a python programm to check if a key exists in a dictionary.

# %%
dic = {
    "name":"jevin",
    "age":18,
    "add":"ahemdabad",
}
a = "add"
if a in dic:
    print("yes your element is exists in a dictionary :")
else:
    print("no your element is not exists in a dictionary :-")
# Out:
# yes your element is exists in a dictionary :

# %% [markdown]
# #### 8. write a python programm to get the keys of a dictionary.

# %%
dic = {
    "name":"jevin",
    "age":18,
    "add":"ahemdabad",
}

a = dic.keys()
print("get the keys of a dictionary :-",a)
# Out:
# get the keys of a dictionary :- dict_keys(['name', 'age', 'add'])

# %% [markdown]
# #### 9. write a python programm to get the values of a dictionary.

# %%
dic = {
    "name":"jevin",
    "age":18,
    "add":"ahemdabad",
}

a = dic.values()

print("get the values of a dictionarty :-",a)
# Out:
# get the values of a dictionarty :- dict_values(['jevin', 18, 'ahemdabad'])

# %% [markdown]
# #### 10 write a python programm to iterate through a dictionary.

# %%
dic = {
    "name":"jevin",
    "age":18,
    "add":"ahemdabad",
}

print("dictionary items :-")
for key,value in dic.items():
    print(key,":",value)
# Out:
# dictionary items :-
# name : jevin
# age : 18
# add : ahemdabad

# %% [markdown]
# #### 11. write a python programm to merge two dictionary

# %%
dic1 = {
    "name":"jevin",
    "age":18,
    "add":"ahemdabad",
}
dic2 = {
    "surname":"kanani",
    "contry":"india",
    "add":"ahemdabad",
}
dic1.update(dic2)

print("merged dictionary :-",dic1)
# Out:
# merged dictionary :- {'name': 'jevin', 'age': 18, 'add': 'ahemdabad', 'surname': 'kanani', 'contry': 'india'}

# %% [markdown]
# #### 12.write a python programm to find the key with the maximum value in a dictionary.

# %%
dic = {
    "jevin":100,
    "bob":92,
    "diana":80,
    "Charlie":68,
}

a = max(dic)
print("maximum keys is a :-",a)
# Out:
# maximum keys is a :- jevin

# %% [markdown]
# #### 13.write a python programm to find the key with the minimum value in a dictionary.

# %%
dic = {
    "jevin":100,
    "bob":92,
    "diana":80,
    "Charlie":68,
}

a = min(dic)
print("minimum keys is :-",a)
# Out:
# minimum keys is :- Charlie

# %% [markdown]
# #### 14. write a python programm to remove all items from a dictionay.

# %%
dic = {
    "jevin":100,
    "bob":92,
    "diana":80,
    "Charlie":68,
}

dic.clear()
print("remove all items from a dictionary :-",dic)
# Out:
# remove all items from a dictionary :- {}

# %% [markdown]
# #### 15. write a python programm to clear a dictionary.

# %%
dic = {
    "jevin":100,
    "bob":92,
    "diana":80,
    "Charlie":68,
}

dic.clear()
print("remove all items from a dictionary :-",dic)
# Out:
# remove all items from a dictionary :- {}

# %% [markdown]
# #### 16. write a python programm to get the items of a dictionary

# %%
dic = {
    "jevin":100,
    "bob":92,
    "diana":80,
    "Charlie":68,
}



print("dictionary itmes :-")

for key,value in dic.items():
    print("key:""value",dic)
# Out:
# dictionary itmes :-
# key:value {'jevin': 100, 'bob': 92, 'diana': 80, 'Charlie': 68}
# key:value {'jevin': 100, 'bob': 92, 'diana': 80, 'Charlie': 68}
# key:value {'jevin': 100, 'bob': 92, 'diana': 80, 'Charlie': 68}
# key:value {'jevin': 100, 'bob': 92, 'diana': 80, 'Charlie': 68}

# %% [markdown]
# #### 17. write a python programm to copy a dictionary.

# %%
dic = {
    "jevin":100,
    "bob":92,
    "diana":80,
    "Charlie":68,
}

a = dic.copy()

# %%
print("org dictionary",dic)
print("copy dictionary",a)
# Out:
# org dictionary {'jevin': 100, 'bob': 92, 'diana': 80, 'Charlie': 68}
# copy dictionary {'jevin': 100, 'bob': 92, 'diana': 80, 'Charlie': 68}

# %% [markdown]
# #### 18. write a python programm ro change the value of a specific key in a dictionary.

# %%
dic = {
    "jevin":100,
    "bob":92,
    "diana":80,
    "Charlie":68,
}

dic["bob"] = 88
print("after change a value a dictionary :-",dic)
# Out:
# after change a value a dictionary :- {'jevin': 100, 'bob': 88, 'diana': 80, 'Charlie': 68}

# %% [markdown]
# #### 19.write a python programm to create a dictionary from two lists.

# %%
keys = ['name','age','city']
values = ['Alice',30,'New york']

dic = dict(zip(keys,values))

print("Created dictionary :")
print(dic)
# Out:
# Created dictionary :
# {'name': 'Alice', 'age': 30, 'city': 'New york'}

# %% [markdown]
# #### 20.write a python programm to check if a dictionary is empty.

# %%
dic = {
    "jevin":100,
    "bob":92,
    "diana":80,
    "Charlie":68,
}

if not dic:
    print("your dictionary is empty :-")
else:
    print("your dictionary is not empty :-")
# Out:
# your dictionary is not empty :-

# %% [markdown]
# #### 21.write a python programm to find if two dictionary are equal.

# %%
dic = {
    "jevin":100,
    "bob":92,
    "diana":80,
    "Charlie":68,
}
dic1= {
    "jevin":100,
    "bob":92,
    "diana":80,
    "Charlie":68,
}

if dic==dic1:
    print("yes dictionary are equal :-")
else:
    print("no dictionary are not equal :-")
# Out:
# yes dictionary are equal :-

# %% [markdown]
# #### 22. write a python programm to merge two dictionary into one.

# %%
dic = {
    "jevin":100,
    "bob":92,
    "diana":80,
    "Charlie":68,
}
dic1 = {
    "janvi":100,
    "dod":92,
    "dina":81,
    "Charle":65,
}

dic.update(dic1)

# %%
print("merge a dictionary is a :",dic)
# Out:
# merge a dictionary is a : {'jevin': 100, 'bob': 92, 'diana': 80, 'Charlie': 68, 'janvi': 100, 'dod': 92, 'dina': 81, 'Charle': 65}
